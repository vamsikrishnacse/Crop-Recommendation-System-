# %%
from wwo_hist import retrieve_hist_data

# set working directory to store output csv file(s)
import os
os.chdir(r"C:\Users\Asus\Desktop\Crop_Prediction_Using_Nutrients\ML\Weather_DL\Data Collection")

# %%
FREQUENCY = 24
START_DATE = '1-JAN-2019'
END_DATE = '1-JULY-2020'
API_KEY = '5b5bf18d10f248999a3162113200911'
LOCATION_LIST = ['coimbatore','nellore',"Rajahmundry","Hyderabad","Tiruchirappalli"]

hist_weather_data = retrieve_hist_data(API_KEY,
                                LOCATION_LIST,
                                START_DATE,
                                END_DATE,
                                FREQUENCY,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for coimbatore
#
#
# Currently retrieving data for coimbatore: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.158490
# Currently retrieving data for coimbatore: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:02.173371
# Currently retrieving data for coimbatore: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.232173
# Currently retrieving data for coimbatore: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:04.323152
# Currently retrieving data for coimbatore: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.415167
# Currently retrieving data for coimbatore: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.443982
# Currently retrieving data for coimbatore: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.606729
# Currently retrieving data for coimbatore: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.720524
# ...

# %%
from pywwo import *
setKey('5b5bf18d10f248999a3162113200911', 'free')
w=LocalWeather('london')
w.data.current_condition.temp_C
w=LocalWeather('sdfasdgasdga')
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Asus\.conda\envs\tensorflow_gpu\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-447f5500aabb>", line 1, in <module>
#     from pywwo import *
#
#   File "C:\Users\Asus\Desktop\Crop_Prediction_Using_Nutrients\ML\Weather_DL\Data Collection\pywwo.py", line 36
#     print "Please set FREE_API_KEY"
#                                   ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Please set FREE_API_KEY")?
